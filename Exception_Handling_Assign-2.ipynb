# %% [markdown]
# ## Q1. Explain why we have to use the Exception class while creating a Custom Exception.

# %% [markdown]
# Jab hum custom error banate hain, toh humein Exception class ka use isliye karna padta hai taaki Python us error ko samajh sake aur handle kar sake. Yeh ensure karta hai ki humara custom error bhi Python ke baaki errors ki tarah kaam kare.

# %% [markdown]
# ## Q2. Write a python program to print Python Exception Hierarchy.

# %%
import sys
import builtins

def print_exception_hierarchy(klass, indent=0):
    print(' ' * indent + klass.__name__)
    for subclass in klass.__subclasses__():
        print_exception_hierarchy(subclass, indent + 2)

# Start from the base Exception class
print("Python Exception Hierarchy:\n")
print_exception_hierarchy(builtins.BaseException)
# Out:
# Python Exception Hierarchy:
#
# BaseException
#   Exception
#     TypeError
#       FloatOperation
#       MultipartConversionError
#     StopAsyncIteration
#     StopIteration
#     ImportError
#       ModuleNotFoundError
#       ZipImportError
#     OSError
#       ConnectionError
#         BrokenPipeError
#         ConnectionAbortedError
#         ConnectionRefusedError
#         ConnectionResetError
#           RemoteDisconnected
#       BlockingIOError
#       ChildProcessError
#       FileExistsError
#       FileNotFoundError
#       IsADirectoryError
#       NotADirectoryError
#       InterruptedError
#         InterruptedSystemCall
#       PermissionError
#       ProcessLookupError
#       TimeoutError
#       UnsupportedOperation
#       itimer_error
#       herror
#       gaierror
#       SSLError
#         SSLCertVerificationError
#         SSLZeroReturnError
#         SSLWantWriteError
#         SSLWantReadError
#         SSLSyscallError
#         SSLEOFError
# ...

# %% [markdown]
# ## Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [markdown]
# 1.FloatingPointError
# 2.OverflowError
# 3.ZeroDivisionError

# %%
## eg.ZeroDivisionError
def test(x) :
    return 30/x

print(test(2))
print(test(0))
# Out:
# 15.0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 6
#       3     return 30/x
#       5 print(test(2))
# ----> 6 print(test(0))
#
# Cell In[3], line 3, in test(x)
#       2 def test(x) :
# ----> 3     return 30/x
#
# ZeroDivisionError: division by zero

# %%
import math
result=math.exp(1000)
print(result)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[6], line 2
#       1 import math
# ----> 2 result=math.exp(1000)
#       3 print(result)
#
# OverflowError: math range error

# %% [markdown]
# ## Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %% [markdown]
# LookupError class Python mein tab use hoti hai jab koi lookup operation fail ho jata hai, jaise list ya dictionary mein galat index ya key access karne par.
# KeyError tab hota hai jab aap dictionary mein non-existent key ko access karte ho.
# IndexError tab hota hai jab list mein invalid index access karne ki koshish karte ho. Dono errors LookupError se inherit karte hain.

# %%
## eg..Key Error
my_dict={'name':'Gaurav','age':20}
print(my_dict['address'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 3
#       1 ## eg..
#       2 my_dict={'name':'Gaurav','age':20}
# ----> 3 print(my_dict['address'])
#
# KeyError: 'address'

# %%
## eg..Key Error
my_list=[1,2,3,4]
print(my_list[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 ## eg..Key Error
#       2 my_list=[1,2,3,4]
# ----> 3 print(my_list[4])
#
# IndexError: list index out of range

# %% [markdown]
# ## Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [markdown]
# 1.ImportError tab hota hai jab Python kisi module ya uske parts ko import nahi kar pata, jaise module missing ho ya galat naam ho.
# 2.ModuleNotFoundError ek specific type hai jo Python 3.6 se introduce hui, aur yeh tab hota hai jab module hi nahi milta. Dono errors module import karne mein problem ke liye hain.

# %% [markdown]
# ## Q6. List down some best practices for exception handling in python.

# %% [markdown]
# 1.Use always a specifi exception
# 2.Print always a proper message
# 3.Always try to logging our error
# 4.Always avoid to write a multiple exception
# 5.Document all the error
# 6.Cleanup all the error
